# %% [markdown]
# # RusStyleModel

# %%
import numpy as np
from vocabulary import Vocabulary, BOS_CODE
from style_dataset import StyleDataset
from dataset import TextDataset
from utils import words_to_sent

voc_path        = "data/rus_style/rus_vocab_2.data"
tr_dataset_path = "data/rus_style/rus_dataset_%d_train_2.data"
va_dataset_path = "data/rus_style/rus_dataset_%d_valid_2.data"
model_path      = 'models/rus/rus-style-model-002/'

# %% [markdown]
# ## Vocabulary

# %%
voc = Vocabulary()
voc.restore(voc_path)
print(voc)
# Out:
# Vocabulary:
#   size: 60004
#   _tokens_to_words: ['<UNK>', '<BOS>', '<EOS>', '<PAD>', ',', '.', 'и', 'в', '—', 'не', 'что', 'на', '«', '»', 'я', 'с', 'он', 'как', '!', 'а']

# %% [markdown]
# ## Dataset

# %%
tr_dataset = StyleDataset(TextDataset)
tr_dataset.restore(tr_dataset_path)
print(tr_dataset)

va_dataset = StyleDataset(TextDataset)
va_dataset.restore(va_dataset_path)
print(va_dataset)
# Out:
# StyleDataset:
#   path_0: data/rus_style/rus_dataset_0_train_2.data
#   path_1: data/rus_style/rus_dataset_1_train_2.data
#   shape: [185840, 26]
#
# StyleDataset:
#   path_0: data/rus_style/rus_dataset_0_valid_2.data
#   path_1: data/rus_style/rus_dataset_1_valid_2.data
#   shape: [185840, 26]

# %% [markdown]
# ## Model

# %%
import os
from utils import make_dir
import numpy as np
import tensorflow as tf
import pickle
from visualization import show_train_stats_ex

class StyleTextDatasetAutoencoder:
    def __init__(self):
        self._scope    = 'style_autoencoder'
        # state
        self.tr_step   = 0
        self.tr_epoch  = 0
        self.tr_losses = []
        self.va_losses = []
    
    
    def save(self, path):
        make_dir(path)
        pickle.dump([self.tr_epoch, self.tr_step, self.tr_losses, self.va_losses], 
                    open(os.path.join(path, "state.p"), "wb"))
        self._saver.save(self._sess, path)
        
        
    def restore(self, path):
        try:
            [self.tr_epoch, self.tr_step, self.tr_losses, self.va_losses] = pickle.load(
                open(os.path.join(path, "state.p"), "rb"))
        except: 
            print("State not found at", path)
        self._saver.restore(self._sess, path)
        
    
    def get_embeddings(self):
        return self.embedding.eval(self._sess)
    
        
    def _make_loss(self, logits, labels):
        loss = tf.nn.sparse_softmax_cross_entropy_with_logits(
            logits = logits,
            labels = labels)
        return tf.reduce_mean(loss)
    

    def _make_optimizer(self, loss, lr, grad_clip):
        tr_vars   = tf.trainable_variables()
        grads, _  = tf.clip_by_global_norm(tf.gradients(loss, tr_vars), grad_clip)
        train_op  = tf.train.AdamOptimizer(lr)
        optimizer = train_op.apply_gradients(zip(grads, tr_vars))
        return optimizer
    
    # =====================================================================
    
    def _make_rnn_cell(self, num_units, num_layers, keep_prob):
        def make_layer():
            l = tf.contrib.rnn.BasicLSTMCell(num_units)
            l = tf.contrib.rnn.DropoutWrapper(l, output_keep_prob=keep_prob)
            return l        
        return tf.contrib.rnn.MultiRNNCell([make_layer() for _ in range(num_layers)])
    
    
    def _make_decoder(self, inp, h, num_units, num_layers, voc_size, seq_len, keep_prob):
        cell = self._make_rnn_cell(num_units, num_layers, keep_prob)
        logits_seq = []

        def loop_function(outputs):
            logits = tf.layers.dense(outputs, voc_size, name='projection')
            token = tf.argmax(logits, axis=1)
            inp = tf.nn.embedding_lookup(self.embedding, token)
            return inp, logits
            
        with tf.variable_scope('decoder', reuse=tf.AUTO_REUSE):
            zeros = tf.zeros_like(h)
            state = (tf.nn.rnn_cell.LSTMStateTuple(zeros, zeros),
                     tf.nn.rnn_cell.LSTMStateTuple(zeros, h))
            
            for t in range(seq_len):
                output, state = cell.apply(inp, state)
                inp, logits = loop_function(output)
                logits_seq.append(tf.expand_dims(logits, 1))

        return tf.concat(logits_seq, axis=1)
    
    
    def build(self, voc_size, bos_token, emb_size, seq_len, num_units, num_layers, grad_clip=5):
        tf.reset_default_graph()
        self._graph = tf.Graph()
        with self._graph.as_default(), tf.variable_scope(self._scope):
            # placeholders
            self.enc_inputs_pl = tf.placeholder(tf.int32, [None, None], name='enc_inputs')
            self.targets_pl    = tf.placeholder(tf.int32, [None, None], name='targets')
            self.styles_pl     = tf.placeholder(tf.int32, shape=[None], name='styles')
            self.batch_size_pl = tf.placeholder(tf.int32, shape=[], name='batch_size')
            self.keep_prob_pl  = tf.placeholder(tf.float32, name='keep_prob')
            self.lr_pl         = tf.placeholder(tf.float32, name='learning_rate')

            # embedding
            self.embedding     = tf.Variable(tf.random_normal(shape=[voc_size, emb_size], dtype=tf.float32))
            en_inputs          = tf.nn.embedding_lookup(self.embedding, self.enc_inputs_pl)
            bos_tokens         = tf.tile([bos_token], tf.expand_dims(self.batch_size_pl,0))  
            de_inputs          = tf.nn.embedding_lookup(self.embedding, bos_tokens)
            
            # encoder
            en_cell            = self._make_rnn_cell(num_units, num_layers, self.keep_prob_pl)
            en_initial_state   = en_cell.zero_state(self.batch_size_pl, tf.float32)
            seq_lens           = tf.tile([seq_len], tf.expand_dims(self.batch_size_pl,0))
            _, en_state        = tf.nn.dynamic_rnn(en_cell, en_inputs, seq_lens, en_initial_state, scope='encoder')
            
            # latent vector = [content, style]
            style_num  = 2
            style_vec  = tf.one_hot(self.styles_pl, style_num)
            content_style = tf.concat([en_state[~0].h, style_vec], axis = 1)

            # decoder
            de_logits = self._make_decoder(
                inp        = de_inputs, 
                h          = content_style, 
                num_units  = num_units+style_num, 
                num_layers = num_layers,
                voc_size   = voc_size,
                seq_len    = seq_len, 
                keep_prob  = self.keep_prob_pl)

            # prediction
            self.outputs       = tf.argmax(tf.nn.softmax(de_logits), axis=2)

            # training
            self.loss_op       = self._make_loss(de_logits, self.targets_pl)
            self.train_op      = self._make_optimizer(self.loss_op, self.lr_pl, grad_clip)
            
            # utils
            self.init_op       = tf.global_variables_initializer()
            self._saver        = tf.train.Saver()

        # session
        self._sess = tf.Session(graph=self._graph)
        self._sess.run(self.init_op)
        
    # =====================================================================
    

    def train(self, tr_dataset, va_dataset, 
              step_num,  batch_size, learning_rate, keep_prob=.5, log_every=20, mean_win=30):
        try:
            data_size = tr_dataset.get_data_size()
            for self.tr_step in range(self.tr_step, step_num-1):
                ep = self.tr_step*batch_size/data_size
                # Train
                sents, styles = tr_dataset.get_next_batch(batch_size)
                tr_loss, _ = self._sess.run(
                    [self.loss_op, self.train_op], 
                    feed_dict = {
                        self.enc_inputs_pl: sents,
                        self.targets_pl   : sents,
                        self.styles_pl    : styles,
                        self.batch_size_pl: batch_size,
                        self.keep_prob_pl : keep_prob,
                        self.lr_pl        : learning_rate,
                })
                self.tr_losses.append(tr_loss)
                # Eval
                if self.tr_step % log_every == log_every-1:
                    sents, styles = va_dataset.get_next_batch(batch_size)
                    va_loss = self._sess.run(
                        self.loss_op, 
                        feed_dict={
                            self.enc_inputs_pl: sents,
                            self.targets_pl   : sents,
                            self.styles_pl    : styles,
                            self.batch_size_pl: batch_size,
                            self.keep_prob_pl : keep_prob,
                            self.lr_pl        : learning_rate,
                        })
                    self.va_losses.extend([va_loss]*log_every)
                    show_train_stats_ex(ep, self.tr_step, self.tr_losses, self.va_losses, mean_win)
                        
        except KeyboardInterrupt:
            show_train_stats_ex(ep, self.tr_step, self.tr_losses, self.va_losses, mean_win)
            

    def run(self, sents, styles, batch_size, seq_length):
        return self._sess.run(
            self.outputs, 
            feed_dict = {
                self.enc_inputs_pl: sents,
                self.targets_pl   : sents,
                self.styles_pl    : styles,
                self.batch_size_pl: batch_size,
                self.keep_prob_pl : 1,
        })

# %% [markdown]
# ## Build

# %%
# %%time
model = StyleAutoencoder()
seq_len = tr_dataset.get_seq_len()
assert seq_len == va_dataset.get_seq_len()

model.build(
    voc_size   = voc.size, 
    bos_token  = BOS_CODE,
    seq_len    = seq_len,
    emb_size   = 300, 
    num_units  = 1000, # 256, 
    num_layers = 2)
# Out:
# CPU times: user 6.78 s, sys: 589 ms, total: 7.37 s
# Wall time: 7.34 s

# %% [markdown]
# ## Train

# %%
# %%time
# %matplotlib inline

model.train(
    step_num      = 200000,
    batch_size    = 64, 
    learning_rate = 1e-3, 
    mean_win      = 30,
    log_every     = 10,
    tr_dataset    = tr_dataset,
    va_dataset    = va_dataset,
)
model.save(model_path)
# Out:
# CPU times: user 1min 37s, sys: 54.2 s, total: 2min 31s
# Wall time: 2min 28s

# %% [markdown]
# ## Test

# %%
batch_size = 50

for dataset in [tr_dataset, va_dataset]:
    print('\n'+'='*80+'\n'+str(dataset))
    inp, styles = dataset.get_next_batch(batch_size)
    out = model.run(inp, 1-styles, batch_size, seq_len)
    # out = model.run(inp, styles, batch_size, seq_len)

    def prepare(s):
        words = voc.to_words(s)
        s = " ".join(words)
        s = s.replace('<BOS>', '[').replace('<EOS>', ']').replace('<PAD>', '').replace('<UNK>', '<?>')
        s = s.replace(' ,', ',').replace(' .', '.').replace(' ?', '?').replace(' !', '!').replace(' :', ':')
        s = s.replace(' )', ')').replace('( ', '(')
        return s

    for i in range(len(inp)):
        print('-'*50)
        s0 = int(styles[i])
        s1 = 1 - s0
        print(s0, prepare(inp[i]))
        print(s1, prepare(out[i]))
# Out:
# ================================================================================
# StyleDataset:
#   path_0: data/rus_style/rus_dataset_0_train_2.data
#   path_1: data/rus_style/rus_dataset_1_train_2.data
#   shape: [185840, 26]
#
# --------------------------------------------------
# 0 [ ну, каков дедушка, такова и внучка, — подумал я. ]
# 1 [ ну, русские честно, безусловно и <?>, — не <?>. ]
# --------------------------------------------------
# 0 [ это изверг! ]
# 1 [ это правильно! ]
# --------------------------------------------------
# 0 [ на вопрос: что мне делать в этом смысле? ]
# 1 [ на вопрос: что вы делать в <?> гончарова? ]
# --------------------------------------------------
# 0 [ ваш товарищ? ]
# 1 [ никакого подробностей? ]
# --------------------------------------------------
# 0 [ — да потому что слишком уж все удачно сошлось и <?> точно как на театре. ]
# 1 [ — да нет что будет бы про <?> <?>,,, <?> <?> <?>. ]
# --------------------------------------------------
# 0 [ скверные, злые и подозрительные глаза <?> жиром и глядели как из <?>. ]
# 1 [ иран, немцов и радикально с <?> <?>, <?> <?> <?> <?>. ]
# --------------------------------------------------
# 0 [ вопрос ведь в том, от дурных ли качеств людей это происходит, или уж оттого, что такова их натура. ]
# 1 [ впоследствии вы в том, у <?> и <?>, <?> <?>, <?>,,, что не в <?>. ]
# --------------------------------------------------
# 0 [ люди были <?>, имели богатство, влияние и силу, меня принимали ласково и радушно. ]
# 1 [ люди были <?>, пишете сверху, <?>,,,, <?>, и <?>. ]
# --------------------------------------------------
# 0 [ так ли я говорю? ]
# 1 [ так ли я говорю? ]
# --------------------------------------------------
# 0 [ однако спустя час он принес мне чаю, и я с жадностью выпил большую чашку. ]
# 1 [ однако спустя дней он решил только <?>, — <?> в <?> и в <?>. ]
# --------------------------------------------------
# 0 [ алеша именно такого характера. ]
# 1 [ алеша именно как-то новым. ]
# --------------------------------------------------
# 0 [ он встал, он приподнял ее из кресел и крепко-крепко прижал ее к сердцу. ]
# 1 [ он встал, как изучал готовился <?> <?> <?>, <?> <?> <?> <?>. ]
# --------------------------------------------------
# 0 [ я и перо затем в руки взял... я, например, ужасно самолюбив. ]
# 1 [ я и будучи себя в эту раз <?>,,, не много попасть. ]
# --------------------------------------------------
# 0 [ <?> рвались из меня с такою силою, и я был так счастлив но что описывать! ]
# 1 [ <?> of из его с фотографией <?>,, что это не <?>, <?> <?>! ]
# --------------------------------------------------
# 0 [ что тогда будет с <?>, подумайте? ]
# 1 [ что их будет с <?>, например? ]
# --------------------------------------------------
# 0 [ — где болван? ]
# 1 [ — где плащ? ]
# --------------------------------------------------
# 0 [ заметил ты, сережа? ]
# 1 [ человек ты, сережа? ]
# --------------------------------------------------
# 0 [ — ну?.. ]
# 1 [ — ну?.. ]
# --------------------------------------------------
# 0 [ и после всего этого он идет теперь с особенною целью, с особою внезапною идеей! ]
# 1 [ и после всего этого не очень вроде <?> <?> <?>, — <?> <?> <?>! ]
# --------------------------------------------------
# 0 [ но ведь есть же и на свете братья у вас благородная душа вы должны это понять, должны!.. ]
# 1 [ но ведь есть же и <?> <?> <?> или <?>, что не не,,, не <?>. ]
# --------------------------------------------------
# 0 [ ему вежливо позволили. ]
# 1 [ ему вежливо позволили. ]
# --------------------------------------------------
# 0 [ лицо ее было больное и бледное ; плохо спала ночью. ]
# 1 [ лицо ее было шло и <?>, <?> <?> <?>. ]
# --------------------------------------------------
# 0 [ бешеные! ]
# 1 [ закрываются! ]
# --------------------------------------------------
# 0 [ <?> в грудь, я подождал секунду или две, и свечка моя, стол и стена передо мною вдруг <?> и <?>. ]
# 1 [ <?> в том, я обнаружил <?> на <?>, <?>, <?>, <?> <?> <?> <?> <?> и <?> <?> <?>. ]
# --------------------------------------------------
# 0 [ <?> ему, он сводит нам огонь с небеси! 68 но вряд ли и на одно поколение людей хватило бы этих восторгов! ]
# 1 [ <?> ей, как праздничный люди <?> на <?>,, <?> <?>, что, <?> <?>,,,, <?>? ]
# --------------------------------------------------
# 1 [ 🍔 (и почему он бургер) все семьи разные, и не существует никакой единственной правильной модели строительства своих отношений с родными. ]
# 0 [ 🍔 (и все он <?> <?> <?> <?> <?> <?>, <?> <?>,,, <?> <?> <?> <?> <?> <?>. ]
# --------------------------------------------------
# 1 [ да и само обучение в зарубежной школе позволяет <?> язык и привыкнуть к новой системе образования. ]
# 0 [ да и петр степанович в русском деле <?> <?>, <?> <?> <?> <?> <?> общества. ]
# --------------------------------------------------
# 1 [ картинка из инстаграма, которая, по данным nyt, использовалась и в фейсбуке. ]
# 0 [ картинка из двор, видимо, в <?>,, <?> <?> <?> <?>. ]
# --------------------------------------------------
# 1 [ что там происходит? в <?> русское лото <?> <?> в 506 миллионов рублей. ]
# 0 [ что там происходит ; в <?> <?> <?> в <?> в в <?>.. ]
# --------------------------------------------------
# 1 [ это самое лучшее, что принесли социальные сети и интернет. ]
# 0 [ это самое болезненное, что старец замирал <?> и <?>. ]
# --------------------------------------------------
# 1 [ 4 а как так? ]
# 0 [ 4 а как так? ]
# --------------------------------------------------
# 1 [ что от этого изменилось? ]
# 0 [ что после этого слышали? ]
# --------------------------------------------------
# 1 [ никто не застрахован от неудачи. ]
# 0 [ никто не сбегал от копейки. ]
# --------------------------------------------------
# 1 [ после этого <?> звонила его матери и рассказывала, что тот занимается политикой. ]
# 0 [ после этого <?> звонила его себя и,, что не и <?>. ]
# --------------------------------------------------
# 1 [ поэтому меня не удивляет количество комментариев сама дура. ]
# 0 [ поэтому меня не удивляет такого себя вполне вполне. ]
# --------------------------------------------------
# 1 [ раньше он выходил из строя по два раза за неделю. ]
# 0 [ зато он выходил из кармана на из с <?> друга. ]
# --------------------------------------------------
# 1 [ и никто мне лучше не сделает. ]
# 0 [ и никто мне надо не забыть. ]
# --------------------------------------------------
# 1 [ по данным минобрнауки, большинство школьников выбирают основы светской этики. ]
# 0 [ по данным достоевского, дело михайловна вдруг его <?> <?>. ]
# --------------------------------------------------
# 1 [ руководство т плюс обвиняют в даче взяток на сумму около 1 миллиарда рублей руководству коми. ]
# 0 [ представители т плюс вниз в даче от в в в в <?> в в <?>. ]
# --------------------------------------------------
# 1 [ также операторов обяжут определять подлинный номер абонента, с которого осуществляются такие звонки. ]
# 0 [ также десятая обяжут определять варвара снизу любви, <?> в <?> и <?>. ]
# --------------------------------------------------
# 1 [ опубликованный 21 ноября материал так и называется: <?> должна быть благодарна ссср за 1968 год: история <?> весны “. ]
# 0 [ c est est pas ; и <?> не <?>, не не <?>,,,, <?> <?> <?> <?>. ]
# --------------------------------------------------
# 1 [ что это такое? ]
# 0 [ что это такое? ]
# --------------------------------------------------
# 1 [ и не бояться того, что <?> тебя вещи не привлекут внимания аудитории. ]
# 0 [ и не бояться того, что у меня меня не не <?> <?>. ]
# --------------------------------------------------
# 1 [ по толпе <?> слухи о <?> ранении в ходе одной из стычек. ]
# 0 [ по <?> <?> слухи <?> <?> <?> в в <?> <?> <?>. ]
# --------------------------------------------------
# 1 [ ответ <?> заявил, что ничего подобного не происходило, а самого <?> он не помнит. ]
# 0 [ ответ <?> том, что теперь ничего не,,,,,, не <?>. ]
# --------------------------------------------------
# 1 [ его точный заработок неизвестен: хакер получал деньги через биткоины, <?> и другие электронные <?>. ]
# 0 [ его превосходительство била человеку: хотелось себе <?> <?> <?>,, <?> <?> <?> <?>. ]
# --------------------------------------------------
# 1 [ кому предъявлены обвинения и в чем, пока не сообщается. ]
# 0 [ кому в. обвинения и в том, что не <?>. ]
# --------------------------------------------------
# 1 [ он также рассказал интерфаксу, что его в очередной раз предупредили об уголовной ответственности за неисполнение решения суда. ]
# 0 [ он также опять положительно, что у в <?> <?> <?>, <?> и и в на мостовой. ]
# --------------------------------------------------
# 1 [ или даже если получится собрать подписи, мы увидим, что людям неинтересно. ]
# 0 [ или даже если хочу знать плакать, и,, что не <?>. ]
# --------------------------------------------------
# 1 [ борис немцов был застрелен 27 февраля 2015 года на большом москворецком мосту в москве. ]
# 0 [ игорь немцов был отправлен 22 августа по года на <?> в с на улице. ]
#
# ================================================================================
# StyleDataset:
#   path_0: data/rus_style/rus_dataset_0_valid_2.data
#   path_1: data/rus_style/rus_dataset_1_valid_2.data
#   shape: [185840, 26]
# --------------------------------------------------
# 0 [ но вскоре улыбка сверкнула на губах его, — улыбка высокомерного торжества и в то же время какого-то тупого <?> изумления. ]
# 1 [ но остаются сша безопасности с 100 <?>, который <?>,,,,, <?> <?> <?> <?> <?> <?>. ]
# --------------------------------------------------
# 0 [ iv наш принц путешествовал три года с лишком, так что в городе почти о нем позабыли. ]
# 1 [ пользователи стала автомобиль меган получил со <?> том, но он <?> <?> <?> <?> <?> <?>. ]
# --------------------------------------------------
# 0 [ только прикоснуться – и сейчас <?>! ]
# 1 [ только прикоснуться – и еще <?>? ]
# --------------------------------------------------
# 0 [ и бьюсь об заклад, предполагаете, что я к вам теперь <?>! ]
# 1 [ и заявление по том, кажется, что не, что не <?>. ]
# --------------------------------------------------
# 0 [ – а главное, – нечего и говорить об этом. ]
# 1 [ – — главное, то важно не <?> с сторону. ]
# --------------------------------------------------
# 0 [ зинаида действительно нахмурилась. ]
# 1 [ войтоловский тоже кошки. ]
# --------------------------------------------------
# 0 [ — вам, единственно вам одному, и единственно для того, чтобы помочь своему развитию! ]
# 1 [ — вам, apple вам люди, что <?> <?> <?>, <?> <?>, <?>? ]
# --------------------------------------------------
# 0 [ она махнула рукой. ]
# 1 [ она обеих навального. ]
# --------------------------------------------------
# 0 [ — я сейчас пошлю к нему взять. ]
# 1 [ — я очень бледна к этим слышал. ]
# --------------------------------------------------
# 0 [ кроме умиления, нравились мне в нем и некоторые чрезвычайно оригинальные иногда воззрения на некоторые весьма еще спорные вещи в современной действительности. ]
# 1 [ кроме кафе, тесто <?> <?> <?> и <?> <?> <?> <?> <?> <?> <?> <?> <?> <?> <?> <?> <?>). ]
# --------------------------------------------------
# 0 [ комедия, и больше ничего! ]
# 1 [ комедия, и ничего ничего! ]
# --------------------------------------------------
# 0 [ танец – это ведь почти объяснение в любви (вспомните <?>), а он точно дерется. ]
# 1 [ танец – это бы было с в зависимости от <?> <?> <?> <?> <?> <?> <?> <?>. ]
# --------------------------------------------------
# 0 [ — вот раскольников! ]
# 1 [ — вот опять! ]
# --------------------------------------------------
# 0 [ в ваших же мыслях и даже в самых словах я не изменил ничего, ни единого слова. ]
# 1 [ в школе же качественно и <?> <?> <?> <?> <?>,,, не <?> <?> <?>. ]
# --------------------------------------------------
# 0 [ через полчаса он уже спорил и шумел с своим адвокатом, но вечером и ночью был опять в <?> и самой фантастической тоске. ]
# 1 [ через полчаса он очень высокий и <?> <?> <?>, <?> <?> <?>,,, <?> <?> <?> <?> <?> <?> <?>. ]
# --------------------------------------------------
# 0 [ — жаль. ]
# 1 [ — понимаю. ]
# --------------------------------------------------
# 0 [ дайте вашу руку, дайте вы тоже дайте вашу, я хочу поцеловать ваши руки здесь, сейчас, на коленах! ]
# 1 [ дайте этому руку, которые мне тоже банки, что не,,,,,,, — не <?>? ]
# --------------------------------------------------
# 0 [ я возвращаюсь в комнату с ламбертом. ]
# 1 [ я училась в комнату на уровне. ]
# --------------------------------------------------
# 0 [ — сказала она, поспешно перебивая меня и вся вспыхнув. ]
# 1 [ — сказала она, сотрудники отношение меня она не <?>. ]
# --------------------------------------------------
# 0 [ вот вы сказали сейчас: у людей на шее <?>. ]
# 1 [ вот вы сказали сейчас не не в на <?> <?>. ]
# --------------------------------------------------
# 0 [ — тайны, секреты! ]
# 1 [ — марш, папаша! ]
# --------------------------------------------------
# 0 [ но можно все исправить и еще развести порошок. ]
# 1 [ но можно все складывалось — очень <?> порошок. ]
# --------------------------------------------------
# 0 [ люби <?> на землю и лобызать ее. ]
# 1 [ слепое <?> на землю и другие деньги. ]
# --------------------------------------------------
# 0 [ — <?>! ]
# 1 [ — <?>! ]
# --------------------------------------------------
# 0 [ о, нестерпимый человек! ]
# 1 [ о, вайнштейн человек! ]
# --------------------------------------------------
# 1 [ жириновский отмечает, что написать <?> его попросили люди, хорошо <?> серебренникова. ]
# 0 [ нил отмечает, что грушенька в <?> же и, и и <?>. ]
# --------------------------------------------------
# 1 [ ну, это же полный абсурд. ]
# 0 [ ну, это же всех расстроены. ]
# --------------------------------------------------
# 1 [ младич командовал армией сербов, которая три года держала в <?> столицу боснии и герцеговины сараево — тогда погибло около 11 тысяч человек. ]
# 0 [ ким командовал i i, которая с с <?> <?> <?> в <?> <?> <?> <?> <?> <?> <?> в в в стола. ]
# --------------------------------------------------
# 1 [ можно добавить немного воды, чтобы добиться нужной вам <?>. ]
# 0 [ можно иметь жизнь отца, чтоб увидите <?> <?> <?>. ]
# --------------------------------------------------
# 1 [ у него было несколько <?>. ]
# 0 [ у него было несколько <?>. ]
# --------------------------------------------------
# 1 [ — санкции не были прописаны в поправках, потому что их содержание описано в законе об иностранных агентах? ]
# 0 [ — небось не будет признаваться в том, а я,,,,,,, <?>? ]
# --------------------------------------------------
# 1 [ что это такое? ]
# 0 [ что это такое? ]
# --------------------------------------------------
# 1 [ на алексея навального составлен протокол об административном нарушении за неоднократные призывы к участию в несогласованных акциях, сообщила пресс-служба гу мвд по москве. ]
# 0 [ на другом павлович павловича минут из подполья земли <?> в в <?>,, <?>,, в в в в глаза. ]
# --------------------------------------------------
# 1 [ на первом месте — эд ширан с песней shape of you, на втором — группа <?> с <?> по <?>. ]
# 0 [ на первом стороны — эд михайловна в <?> <?> <?> <?> <?>,,,, <?> <?> <?> <?> <?>. ]
# --------------------------------------------------
# 1 [ сколько человек находились на борту, не уточняется. ]
# 0 [ сколько человек случая на земле, то думаю. ]
# --------------------------------------------------
# 1 [ северная корея за последнее время провела серию ракетных испытаний, а в начале сентября испытала ядерное оружие. ]
# 0 [ северная корея за нами прежде весьма ее <?> <?>, <?> <?> и <?> и на <?>. ]
# --------------------------------------------------
# 1 [ решение было <?> несколькими группами, которые занимаются развитием здравоохранения и защитой прав человека. ]
# 0 [ решение было <?> несколькими обыкновенного, чтобы <?> <?> <?> и и <?> <?>. ]
# --------------------------------------------------
# 1 [ я сделала очень мало. ]
# 0 [ я знала очень знаю. ]
# --------------------------------------------------
# 1 [ 15 ноября создатели игры решились ответить на вопросы пользователей reddit. ]
# 0 [ глава павлович достоевский легко решились ответить с ним <?> <?>. ]
# --------------------------------------------------
# 1 [ российские власти против шифрования в telegram. ]
# 0 [ российские власти опять обратились в недоумении. ]
# --------------------------------------------------
# 1 [ есть местный ислам. ]
# 0 [ есть поклон покоробило. ]
# --------------------------------------------------
# 1 [ многие британские солдаты пытались помочь раненым туркам, однако были вынуждены отказаться от этого из-за <?> <?> огня с <?> стороны. ]
# 0 [ эти британские солдаты друг ему интересовался существо, но он <?>, <?> <?>,, в <?> в в <?>. ]
# --------------------------------------------------
# 1 [ теперь она живет в большом открытом <?>. ]
# 0 [ теперь она живет в большом сторону <?>! ]
# --------------------------------------------------
# 1 [ 9 наверное, такое обучение — для маленьких компаний, которые не могут позволить себе полноценные тренинги? ]
# 0 [ 8 важно, отчего бога, <?> в <?>, что я,,,, <?>? ]
# --------------------------------------------------
# 1 [ в числе прочих эвакуация торговых центров, учебных заведений и другие учреждений проводилась в москве и санкт-петербурге. ]
# 0 [ в некоторых минуту послышались почтительность степанович, госпожа страшной, и,,, и и кровати. ]
# --------------------------------------------------
# 1 [ <?> работы нескольких мусорных полигонов в московской области, которые предполагалось закрыть, будет продлен, сообщил рбк министр экологии региона александр коган. ]
# 0 [ <?> место своего мусорных визг в своей <?>, и <?>,,,,,, <?>, <?> в <?> байрона. ]
# --------------------------------------------------
# 1 [ мне не нужны широкие лбы, <?> лица, нет. ]
# 0 [ мне не хотел бедную положения, <?> <?>, наверно. ]
# --------------------------------------------------
# 1 [ война между сепаратистами и регулярной украинской армией не закончена. ]
# 0 [ война ее богатство и разнообразие стихов <?>, <?>. ]
# --------------------------------------------------
# 1 [ это произошло в художественной галерее на открытии <?> ; в этот момент карлова, <?> перед <?>, снимали на фото и видео. ]
# 0 [ это произошло в калитку мгновение по <?> <?>, <?> <?>,,,,,,, <?> <?> <?> <?> <?>. ]
# --------------------------------------------------
# 1 [ спустя полгода украинская прокуратура отчиталась об итогах расследования и назвала предполагаемого заказчика преступления. ]
# 0 [ спустя недели небрежно степана cominges по лицу <?> и <?> <?> <?> <?>. ]

# %% [markdown]
# ## Restore

# %%
model.restore(model_path)
# Out:
# INFO:tensorflow:Restoring parameters from models/math/style-autoencoder-002/
